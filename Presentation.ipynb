# %% [markdown]
# <h1> <b> Comercial Leads in Porto Alegre - Brazil

# %% [markdown]
# <b> Introduction

# %% [markdown]
#  I work in a junior company where we sell products on energy efficiency. So, it would be very usefull por comercial leads if we had types of venues per neighborhood.

# %% [markdown]
# <b> Data

# %% [markdown]
# First, we need the list of neighborhoods of my city, Porto Alegre. We can find it in the wikipedia link: https://pt.wikipedia.org/wiki/Lista_de_bairros_de_Porto_Alegre. And the coordinates of each neighborhood; the coordinates are in my github, named: POAbairros3.csv .

# %% [markdown]
# <b> Methodology

# %% [markdown]
# For methodology, we need to obtain the data from the wikipedia using beautifulsoup. Then we need to clean the data, take everything that is useful and the things that are not.
# We can take the coordinates from the second file and merge together, dropping everything that is repeated, corropted, or simply has lack of data.
# Than, we can use foursquare to retrieve the venues and venues types per neighborhood and store the information in another dataframe.
# By working the last dataframe, we can merge everything, and count the most frequent venues types per neighborhood. Concluding the project.

# %% [markdown]
# <b> Results

# %%
import pandas as pd
df=pd.read_csv("/home/arthur/Documents/final_table2.csv",delimiter=',')
df
# Out:
#     Unnamed: 0    Neighborhood       1st Most Common Venue  \
# 0            0       Agronomia  Construction & Landscaping
# 1            1        Anchieta                     Brewery
# 2            2     Arquipélago                  Restaurant
# 3            3          Azenha                        Café
# 4            4      Bela Vista        Gym / Fitness Center
# ..         ...             ...                         ...
# 66          66  Três Figueiras           Convenience Store
# 67          67   Vila Assunção                       Plaza
# 68          68   Vila Ipiranga                        Park
# 69          69     Vila Jardim                 Pizza Place
# 70          70       Vila Nova                Burger Joint
#
#       2nd Most Common Venue 3rd Most Common Venue 4th Most Common Venue  \
# 0              Churrascaria           Bus Station              Bus Stop
# 1               Supermarket  Brazilian Restaurant   Arts & Crafts Store
# ...

# %% [markdown]
# <b> Discution

# %% [markdown]
# We can see that there are loots of different types of venues, but we can see that "churrascarias" that means "barbecue restaurants" are one of the most popular places. We can see a lot of Soccer Fields, Night Clubs and many types of different restaurants.

# %% [markdown]
# <b> Conclusion

# %% [markdown]
# After me and my comercial director analise the data, we had the conclusion that we have to enhance our restaurant products.
